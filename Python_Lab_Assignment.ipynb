# %% [markdown]
# # PyCity Schools Analysis
#
# * As a whole, schools with higher budgets, did not yield better test results. By contrast, schools with higher spending per student actually (\\$645 - 675) underperformed compared to schools with smaller budgets (\\$585 per student).
#
# * As a whole, smaller and medium sized schools dramatically out-performed large sized schools on passing math performances (89-91% passing vs 67%).
#
# * As a whole, charter schools out-performed the public district schools across all metrics. However, more analysis will be required to glean if the effect is due to school practices or the fact that charter schools tend to serve smaller student populations per school.
# ---

# %% [markdown]
# **Note:**
# Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load (Remember to Change These)
school_data_to_load = "data/schools_complete.csv"
student_data_to_load = "data/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])
school_data_complete.head()


# school_data_complete.count()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Create a District Summary
school_data_complete.describe()
school_data_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39170 entries, 0 to 39169
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student ID     39170 non-null  int64
#  1   student_name   39170 non-null  object
#  2   gender         39170 non-null  object
#  3   grade          39170 non-null  object
#  4   school_name    39170 non-null  object
#  5   reading_score  39170 non-null  int64
#  6   math_score     39170 non-null  int64
#  7   School ID      39170 non-null  int64
#  8   type           39170 non-null  object
#  9   size           39170 non-null  int64
#  10  budget         39170 non-null  int64
# dtypes: int64(6), object(5)
# memory usage: 3.6+ MB

# %%
# Total number of schools

total_number_of_school= school_data_complete['school_name'].value_counts()
total_number_of_school.count()
# Out:
# 15

# %%
# Total number of students
len(school_data_complete)
# Out:
# 39170

# %%
# Total budget


school_data_complete['budget'].sum()
# Out:
# 82932329558

# %%
# Average math score


school_data_complete['math_score'].mean()
# Out:
# 78.98537145774827

# %%
# Average reading score

school_data_complete['reading_score'].mean()
# Out:
# 81.87784018381414

# %%
# Overall average score

total= (school_data_complete['reading_score'].mean()+school_data_complete['math_score'].mean())/2
total
# Out:
# 80.43160582078121

# %%
# Percentage of passing math (70 or greater)

new_Sup70maths=school_data_complete[school_data_complete['math_score'] >= 70]
X=len(school_data_complete)
Y=len(new_Sup70maths)
Percentage= Y/X *100
print(Percentage)
# Out:
# 74.9808526933878

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# * Create a dataframe to hold the above results

# %% [markdown]
# ### Top Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the top five schools in overall passing rate

# %%
#  Sort and display the top five schools in overall passing rate

Sup_70_reading_and_maths_by_school=school_data_complete[(school_data_complete['reading_score'] >= 70) & (school_data_complete['math_score'] >= 70)].groupby('school_name').groups
student_by_school=school_data_complete.groupby('school_name').groups
liste1=[]


for i,j in zip(Sup_70_reading_and_maths_by_school.keys(), student_by_school.keys()) :
    list_school_sup_70=Sup_70_reading_and_maths_by_school.get(i)
    list_school_global=student_by_school.get(j)
    x=len(list_school_sup_70)
    y=len(list_school_global)
    liste1.append(x/y*100)


#cration of a new dictionnaire according to their passage rate 
dict_from_list=dict(zip(student_by_school.keys(), liste1))

#sort by rate 
list2=sorted(dict_from_list.values())
final_list=list2[10:]

# give the school linked to the 5 highest rates
for cle,valeur in dict_from_list.items():
    if valeur in final_list :
        print(cle)
# Out:
# Cabrera High School
# Griffin High School
# Pena High School
# Thomas High School
# Wilson High School

# %%
# Calculate total school budget

buget_by_school=school_data_complete.groupby('school_name')['budget'].sum()
buget_by_school
# Out:
# school_name
# Bailey High School       15549641728
# Cabrera High School       2009159448
# Figueroa High School      5557128039
# Ford High School          4831365924
# Griffin High School       1346890000
# Hernandez High School    14007062700
# Holden High School         105933149
# Huang High School         5573322295
# Johnson High School      14733628650
# Pena High School           563595396
# Rodriguez High School    10186904637
# Shelton High School       1860672600
# Thomas High School        1705517550
# Wilson High School        3012587442
# Wright High School        1888920000
# Name: budget, dtype: int64

# %%
# Calculate per student budget

total_student_by_school=school_data_complete.groupby('school_name')['Student ID'].count()

budget_per_student_avg_by_school=(buget_by_school/total_student_by_school)
budget_per_student_avg_by_school
# Out:
# school_name
# Bailey High School       3124928.0
# Cabrera High School      1081356.0
# Figueroa High School     1884411.0
# Ford High School         1763916.0
# Griffin High School       917500.0
# Hernandez High School    3022020.0
# Holden High School        248087.0
# Huang High School        1910635.0
# Johnson High School      3094650.0
# Pena High School          585858.0
# Rodriguez High School    2547363.0
# Shelton High School      1056600.0
# Thomas High School       1043130.0
# Wilson High School       1319574.0
# Wright High School       1049400.0
# dtype: float64

# %%
# Cacluate the avg math and reading score

Avg_reading_by_school=school_data_complete.groupby('school_name')['reading_score'].mean()
Avg_math_by_school=school_data_complete.groupby('school_name')['math_score'].mean()
avg_both=(Avg_reading_by_school+Avg_math_by_school)/2

avg_both
# Out:
# school_name
# Bailey High School       79.041198
# Cabrera High School      83.518837
# Figueroa High School     78.934893
# Ford High School         78.924425
# Griffin High School      83.584128
# Hernandez High School    79.112082
# Holden High School       83.809133
# Huang High School        78.906068
# Johnson High School      79.019429
# Pena High School         83.942308
# Rodriguez High School    78.793698
# Shelton High School      83.542589
# Thomas High School       83.633639
# Wilson High School       83.631844
# Wright High School       83.818611
# dtype: float64

# %% [markdown]
# #### Find the passing rate for math and reading (above 70 points)

# %%
Sup_70_reading_and_maths_by_school=school_data_complete[(school_data_complete['reading_score'] >= 70) & (school_data_complete['math_score'] >= 70)].groupby('school_name').groups
student_by_school=school_data_complete.groupby('school_name').groups
liste1=[]


for i,j in zip(Sup_70_reading_and_maths_by_school.keys(), student_by_school.keys()) :
    list_school_sup_70=Sup_70_reading_and_maths_by_school.get(i)
    list_school_global=student_by_school.get(j)
    x=len(list_school_sup_70)
    y=len(list_school_global)
    liste1.append(x/y*100)


#cration of a new dictionnaire according to their passage rate 
dict_from_list=dict(zip(student_by_school.keys(), liste1))
dict_from_list
# Out:
# {'Bailey High School': 54.64228295819936,
#  'Cabrera High School': 91.33476856835307,
#  'Figueroa High School': 53.20447609359105,
#  'Ford High School': 54.289886820007304,
#  'Griffin High School': 90.59945504087193,
#  'Hernandez High School': 53.52750809061489,
#  'Holden High School': 89.22716627634661,
#  'Huang High School': 53.51388412752828,
#  'Johnson High School': 53.53917244276413,
#  'Pena High School': 90.54054054054053,
#  'Rodriguez High School': 52.988247061765435,
#  'Shelton High School': 89.89210675752413,
#  'Thomas High School': 90.94801223241589,
#  'Wilson High School': 90.58256679807272,
#  'Wright High School': 90.33333333333333}

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %% [markdown]
# ### Bottom Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the five worst-performing schools

# %%
#  Sort and display the worst five schools in overall passing rate
Sup_70_reading_and_maths_by_school=school_data_complete[(school_data_complete['reading_score'] >= 70) & (school_data_complete['math_score'] >= 70)].groupby('school_name').groups
student_by_school=school_data_complete.groupby('school_name').groups
liste1=[]


for i,j in zip(Sup_70_reading_and_maths_by_school.keys(), student_by_school.keys()) :
    list_school_sup_70=Sup_70_reading_and_maths_by_school.get(i)
    list_school_global=student_by_school.get(j)
    x=len(list_school_sup_70)
    y=len(list_school_global)
    liste1.append(x/y*100)


#cration of a new dictionnaire according to their passage rate 
dict_from_list=dict(zip(student_by_school.keys(), liste1))

#sort by rate 
list2=sorted(dict_from_list.values())
final_list=list2[:5]

# give the school linked to the 5 highest rates
for cle,valeur in dict_from_list.items():
    if valeur in final_list :
        print(cle)
# Out:
# Figueroa High School
# Hernandez High School
# Huang High School
# Johnson High School
# Rodriguez High School

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
# Create table that lists the average math score for each school of each grade level.


total_student_avg=school_data_complete.groupby(['school_name','grade'])['math_score'].mean()

total_student_avg
# Out:
# school_name            grade
# Bailey High School     10th     76.996772
#                        11th     77.515588
#                        12th     76.492218
#                        9th      77.083676
# Cabrera High School    10th     83.154506
#                        11th     82.765560
#                        12th     83.277487
#                        9th      83.094697
# Figueroa High School   10th     76.539974
#                        11th     76.884344
#                        12th     77.151369
#                        9th      76.403037
# Ford High School       10th     77.672316
#                        11th     76.918058
#                        12th     76.179963
#                        9th      77.361345
# Griffin High School    10th     84.229064
#                        11th     83.842105
#                        12th     83.356164
#                        9th      82.044010
# Hernandez High School  10th     77.337408
#                        11th     77.136029
# ...

# %%
# Calculate the average math score for 10th grade in each school

in_frame= total_student_avg.to_frame()

in_frame.loc(axis=0)[:,"11th", :]
# Out:
#                              math_score
# school_name           grade
# Bailey High School    11th    77.515588
# Cabrera High School   11th    82.765560
# Figueroa High School  11th    76.884344
# Ford High School      11th    76.918058
# Griffin High School   11th    83.842105
# Hernandez High School 11th    77.136029
# Holden High School    11th    85.000000
# Huang High School     11th    76.446602
# Johnson High School   11th    77.491653
# Pena High School      11th    84.328125
# Rodriguez High School 11th    76.395626
# Shelton High School   11th    83.383495
# Thomas High School    11th    83.498795
# Wilson High School    11th    83.195326
# Wright High School    11th    83.836782

# %%
# Calculate the average math score for 11th grade in each school

in_frame.loc(axis=0)[:,"11th", :]
# Out:
#                              math_score
# school_name           grade
# Bailey High School    11th    77.515588
# Cabrera High School   11th    82.765560
# Figueroa High School  11th    76.884344
# Ford High School      11th    76.918058
# Griffin High School   11th    83.842105
# Hernandez High School 11th    77.136029
# Holden High School    11th    85.000000
# Huang High School     11th    76.446602
# Johnson High School   11th    77.491653
# Pena High School      11th    84.328125
# Rodriguez High School 11th    76.395626
# Shelton High School   11th    83.383495
# Thomas High School    11th    83.498795
# Wilson High School    11th    83.195326
# Wright High School    11th    83.836782

# %%
# Calculate the average math score for 12th grade in each school

in_frame.loc(axis=0)[:,"12th", :]
# Out:
#                              math_score
# school_name           grade
# Bailey High School    12th    76.492218
# Cabrera High School   12th    83.277487
# Figueroa High School  12th    77.151369
# Ford High School      12th    76.179963
# Griffin High School   12th    83.356164
# Hernandez High School 12th    77.186567
# Holden High School    12th    82.855422
# Huang High School     12th    77.225641
# Johnson High School   12th    76.863248
# Pena High School      12th    84.121547
# Rodriguez High School 12th    77.690748
# Shelton High School   12th    83.778976
# Thomas High School    12th    83.497041
# Wilson High School    12th    83.035794
# Wright High School    12th    83.644986

# %% [markdown]
# ### Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
# Create table that lists the average reading score for each school of each grade level.

total_student_avg=school_data_complete.groupby(['school_name','grade'])['reading_score'].mean()
in_frame2= total_student_avg.to_frame()
in_frame2
# Out:
#                              reading_score
# school_name           grade
# Bailey High School    10th       80.907183
#                       11th       80.945643
#                       12th       80.912451
#                       9th        81.303155
# Cabrera High School   10th       84.253219
#                       11th       83.788382
#                       12th       84.287958
#                       9th        83.676136
# Figueroa High School  10th       81.408912
#                       11th       80.640339
#                       12th       81.384863
#                       9th        81.198598
# Ford High School      10th       81.262712
#                       11th       80.403642
#                       12th       80.662338
#                       9th        80.632653
# Griffin High School   10th       83.706897
#                       11th       84.288089
#                       12th       84.013699
#                       9th        83.369193
# ...

# %%
# Calculate the average reading score for 9th grade in each school

in_frame2.loc(axis=0)[:,"9th", :]
# Out:
#                              reading_score
# school_name           grade
# Bailey High School    9th        81.303155
# Cabrera High School   9th        83.676136
# Figueroa High School  9th        81.198598
# Ford High School      9th        80.632653
# Griffin High School   9th        83.369193
# Hernandez High School 9th        80.866860
# Holden High School    9th        83.677165
# Huang High School     9th        81.290284
# Johnson High School   9th        81.260714
# Pena High School      9th        83.807273
# Rodriguez High School 9th        80.993127
# Shelton High School   9th        84.122642
# Thomas High School    9th        83.728850
# Wilson High School    9th        83.939778
# Wright High School    9th        83.833333

# %%
# Calculate the average reading score for 10th grade in each school

in_frame2.loc(axis=0)[:,"10th", :]
# Out:
#                              reading_score
# school_name           grade
# Bailey High School    10th       80.907183
# Cabrera High School   10th       84.253219
# Figueroa High School  10th       81.408912
# Ford High School      10th       81.262712
# Griffin High School   10th       83.706897
# Hernandez High School 10th       80.660147
# Holden High School    10th       83.324561
# Huang High School     10th       81.512386
# Johnson High School   10th       80.773431
# Pena High School      10th       83.612000
# Rodriguez High School 10th       80.629808
# Shelton High School   10th       83.441964
# Thomas High School    10th       84.254157
# Wilson High School    10th       84.021452
# Wright High School    10th       83.812757

# %%
# Calculate the average reading score for 11th grade in each school

in_frame.loc(axis=0)[:,"11th", :]
# Out:
#                              math_score
# school_name           grade
# Bailey High School    11th    77.515588
# Cabrera High School   11th    82.765560
# Figueroa High School  11th    76.884344
# Ford High School      11th    76.918058
# Griffin High School   11th    83.842105
# Hernandez High School 11th    77.136029
# Holden High School    11th    85.000000
# Huang High School     11th    76.446602
# Johnson High School   11th    77.491653
# Pena High School      11th    84.328125
# Rodriguez High School 11th    76.395626
# Shelton High School   11th    83.383495
# Thomas High School    11th    83.498795
# Wilson High School    11th    83.195326
# Wright High School    11th    83.836782

# %%
# Calculate the average reading score for 12th grade in each school

in_frame2.loc(axis=0)[:,"12th", :]
in_frame2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 60 entries, ('Bailey High School', '10th') to ('Wright High School', '9th')
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   reading_score  60 non-null     float64
# dtypes: float64(1)
# memory usage: 1.0+ KB

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Sample bins. Feel free to create your own bins.
school_data_complete.tail()
# Out:
#        Student ID     student_name gender grade         school_name  \
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID     type  size   budget
# 39165             99          90         14  Charter  1635  1043130
# 39166             95          70         14  Charter  1635  1043130
# 39167             73          84         14  Charter  1635  1043130
# 39168             99          90         14  Charter  1635  1043130
# 39169             95          75         14  Charter  1635  1043130

# %%
# Create a new column to show budget per student in each row

total_student_by_school=school_data_complete.groupby('school_name')['Student ID'].count()
budget_per_student_avg_by_school=(buget_by_school/total_student_by_school)

#creation of frame to take corresponding values 
frame_budget_per_student_avg_by_school=budget_per_student_avg_by_school.to_frame()
frame_budget_per_student_avg_by_school= frame_budget_per_student_avg_by_school.rename_axis('school_name').reset_index()

frame_budget_per_student_avg_by_school.columns=['school_name','budget_per_student']

# creation of the categories correponding to the expense (1 is the cheapest)
categorie=[]
for i in frame_budget_per_student_avg_by_school['budget_per_student']:
    if ( i< 1081356):
        categorie.append(1)
    elif (i<2.228999e+06):
        categorie.append(2)
    elif (i >= 2.228999e+06):
        categorie.append(3)
        
frame_budget_per_student_avg_by_school=frame_budget_per_student_avg_by_school.assign(budget_per_student_range1=categorie)
        
frame_budget_per_student_avg_by_school.head()
# Out:
#             school_name  budget_per_student  budget_per_student_range1
# 0    Bailey High School           3124928.0                          3
# 1   Cabrera High School           1081356.0                          2
# 2  Figueroa High School           1884411.0                          2
# 3      Ford High School           1763916.0                          2
# 4   Griffin High School            917500.0                          1

# %%
l=[]
K=0

for i in range(15):
    K=frame_budget_per_student_avg_by_school.iloc[i,0] 
    for j in range(39170):
        R=school_data_complete.iloc[j,4]
        if R==K:
            l.append(frame_budget_per_student_avg_by_school.iloc[i,2])


print(l)
# Out:
# [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3
# ...

# %%
school_data_complete= school_data_complete.assign(budget_per_student_range=l)

# %%
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget  \
# ...

# %%
# Calculate the average math score within each spending range

school_data_complete.groupby('budget_per_student_range')['math_score'].mean()
# Out:
# budget_per_student_range
# 1    79.627716
# 2    78.096893
# 3    79.320233
# Name: math_score, dtype: float64

# %%
# Calculate the percentage passing rate for math in each spending range


passing_rate_math= school_data_complete[school_data_complete['math_score']>= 70]

pasing_rate_linked_bins = (passing_rate_math.groupby('budget_per_student_range').count()/school_data_complete.groupby('budget_per_student_range').count())*100

r= pasing_rate_linked_bins.iloc[:,1]
r
# Out:
# budget_per_student_range
# 1    77.138954
# 2    71.285109
# 3    76.598988
# Name: student_name, dtype: float64

# %%
# Calculate the percentage passing rate for reading in each spending range

school_data_complete.groupby('budget_per_student_range')['reading_score'].mean()
# Out:
# budget_per_student_range
# 1    82.140196
# 2    81.363016
# 3    82.120026
# Name: reading_score, dtype: float64

# %%
# Calculate the percentage overall passing rate in each spending range


passing_rate_reading= school_data_complete[school_data_complete['reading_score']>= 70]

pasing_rate_linked_reading= (passing_rate_math.groupby('budget_per_student_range').count()/school_data_complete.groupby('budget_per_student_range').count())*100

g= pasing_rate_linked_bins.iloc[:,1]
g
# Out:
# budget_per_student_range
# 1    77.138954
# 2    71.285109
# 3    76.598988
# Name: student_name, dtype: float64

# %% [markdown]
# ### Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Sample bins. Feel free to create your own bins.

school_data_complete.groupby('school_name')['Student ID'].count()


school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget  \
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635
#
#    budget_per_student_range
# 0                         3
# 1                         3
# 2                         3
# 3                         3
# 4                         3

# %%
# Create a new column for the bin groups

total_student_by_school=school_data_complete.groupby('school_name')['Student ID'].count()
budget_per_student_avg_by_school=(buget_by_school/total_student_by_school)

#creation of frame to take corresponding values 
frame_high_school_size=total_student_by_school.to_frame()
frame_high_school_size= frame_high_school_size.rename_axis('school_name').reset_index()

frame_high_school_size.columns=['school_name','size']

# creation of the categories correponding to the size (1 is the smallest)
categorie1=[]
for i in frame_high_school_size['size']:
    if ( i< 1000):
        categorie1.append(1)
    elif (i<2000):
        categorie1.append(2)
    elif (i >= 2000):
        categorie1.append(3)
        
frame_high_school_size=frame_high_school_size.assign(size_school_range=categorie1)
        
frame_high_school_size
# Out:
#               school_name  size  size_school_range
# 0      Bailey High School  4976                  3
# 1     Cabrera High School  1858                  2
# 2    Figueroa High School  2949                  3
# 3        Ford High School  2739                  3
# 4     Griffin High School  1468                  2
# 5   Hernandez High School  4635                  3
# 6      Holden High School   427                  1
# 7       Huang High School  2917                  3
# 8     Johnson High School  4761                  3
# 9        Pena High School   962                  1
# 10  Rodriguez High School  3999                  3
# 11    Shelton High School  1761                  2
# 12     Thomas High School  1635                  2
# 13     Wilson High School  2283                  3
# 14     Wright High School  1800                  2

# %%
G=[]


for i in range(15):
    p=frame_high_school_size.iloc[i,0] 
    for j in range(39170):
        R=school_data_complete.iloc[j,4]
        if R==K:
            G.append(frame_high_school_size.iloc[i,2])

print(len(G))
# Out:
# 27000

# %%
school_data_complete= school_data_complete.assign(size_range=G)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-211-002139a6aada> in <module>
# ----> 1 school_data_complete= school_data_complete.assign(size_range=G)
#       2
#       3
#       4
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in assign(self, **kwargs)
#    3693
#    3694         for k, v in kwargs.items():
# -> 3695             data[k] = com.apply_if_callable(v, data)
#    3696         return data
#    3697
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3114         """
# ...

# %% [markdown]
# Look for the total count of test scores that pass 70% or higher

# %%
# math_pass_size
school_data_complete['size']
# Out:
# 0        2917
# 1        2917
# 2        2917
# 3        2917
# 4        2917
#          ...
# 39165    1635
# 39166    1635
# 39167    1635
# 39168    1635
# 39169    1635
# Name: size, Length: 39170, dtype: int64

# %%
# read_pass_size

# %%
# Calculate the overall passing rate for different school size

# %% [markdown]
# ### Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type.

# %%
# Create bins and groups, school type {'Charter', 'District'}

# %% [markdown]
# Find counts of the passing 70 or higher score for the both test

# %%
# math pass size

# %%
# reading pass size

# %%
# Calculate the overall passing rate
